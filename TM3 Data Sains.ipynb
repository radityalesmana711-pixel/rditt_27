# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("titanic.csv")

print("Raditya Lesmana | 15240074 | 15.3A.01 ")
print("\n============= 1. Mean values =============")
mean_age = df['age'].mean()
mean_fare = df['fare'].mean()
mean_survived = df['survived'].mean()
mean_pclass = df['pclass'].mean()
print("Mean Age:", mean_age)
print("Mean Fare:", mean_fare)
print("Mean Survived:", mean_survived)
print("Mean Pclass:", mean_pclass)

print("\n============= 2. Max & Min =============")
max_age = df['age'].max()
min_age = df['age'].min()
max_fare = df['fare'].max()
min_fare = df['fare'].min()
print("Max Age:", max_age, " | Min Age:", min_age)
print("Max Fare:", max_fare, " | Min Fare:", min_fare)

print("\n============= 3. Outliers Fare & Visual Data =============")
Q1 = df['fare'].quantile(0.25)
Q3 = df['fare'].quantile(0.75)
IQR = Q3-Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
outliers = df[(df['fare'] < lower_limit) | (df['fare'] > upper_limit)]

print(outliers.head())

plt.figure(figsize=(6,4))
plt.boxplot(df['fare'].dropna())
plt.title("Boxplot Fare (Outliers)")
plt.ylabel("Fare")
plt.show()
# Out:
# Raditya Lesmana | 15240074 | 15.3A.01
#
# ============= 1. Mean values =============
# Mean Age: 29.69911764705882
# Mean Fare: 34.694514005602244
# Mean Survived: 0.4061624649859944
# Mean Pclass: 2.2366946778711485
#
# ============= 2. Max & Min =============
# Max Age: 80.0  | Min Age: 0.42
# Max Fare: 512.3292  | Min Fare: 0.0
#
# ============= 3. Outliers Fare & Visual Data =============
#     survived  pclass                                      name     sex   age  \
# 23         0       1            Fortune, Mr. Charles Alexander    male  19.0
# 26         0       1                   Meyer, Mr. Edgar Joseph    male  28.0
# 38         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# 46         1       1                       Icard, Miss. Amelie  female  38.0
# 47         0       1               Harris, Mr. Henry Birkhardt    male  45.0
#
#         fare  sibsp  parch
# 23  263.0000      3      2
# 26   82.1708      1      0
# 38   76.7292      1      0
# ...
